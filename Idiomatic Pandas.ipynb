# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Before Getting Started
# Make sure you:
# * Have [Anaconda installed](https://www.anaconda.com/download)
# * Have pandas version 0.21 - use command **`conda update pandas`**
#
# ## Overview
# * Pandas is one of the most popular tools to do data analysis with. Approximately 1% of all new Stack Overflow questions are tagged as pandas.
# * The library has evolved substantially since it started becoming mainstream in 2012
# * Many answers on Stack Overflow have older syntax that has not been updated
# * There are multiple ways to accomplish the same task
# * For beginners, there is not always an obvious way of doing it
# * Lots of confusion and easy to write inefficient pandas
#
# ## Confusing row and column labels (index)
# * The labeled row and columns (called indexes) are one of the key contributors to the confusion
# * You must understand that pandas implicitly (silently) automatically aligns data by the labels in the row
# * Adding to the confusion is that pandas allows for multiple-level indexes called **hierarchical indexing**
# * One of the biggest changes to the library is the deprecation of the **`ix`** indexer
#
# ## Topics
# * `read_csv` vs `read_table`
# * Selecting subsets of data with `[]`, `.loc`, and `.iloc`
# * Automatic alignment of the index
# * Pandas methods vs Python functions
# * `map` vs `apply`
# * Why I almost never use `apply`

# %% [markdown]
# ## `read_csv` vs `read_table`
# If you have heard of both of these  functions, do you know the difference between them? They are actually use the same underlying code with one minor difference.
# * `read_csv` uses a comma as its default delimiter
# * `read_table` uses a tab as its default delimiter

# %%
movie = pd.read_csv('data/movie.csv')

# %%
movie2 = pd.read_table('data/movie.csv', sep=',')

# %% [markdown]
# ### Incorporate equality checking to ensure accurate results

# %%
movie.equals(movie2)
# Out:
# True

# %% [markdown]
# ### Know the components of the DataFrame - The index, the columns and the data (values)

# %%
movie.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy
# 2                 11000.0  200074175.0        Action|Adventure|Thriller
# 3                 27000.0  448130642.0                  Action|Thriller
# 4                   131.0          NaN                      Documentary
#
#           ...          num_user_for_reviews language  country  content_rating  \
# 0         ...                        3054.0  English      USA           PG-13
# 1         ...                        1238.0  English      USA           PG-13
# 2         ...                         994.0  English       UK           PG-13
# 3         ...                        2701.0  English      USA           PG-13
# 4         ...                           NaN      NaN      NaN             NaN
#
#         budget  title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0  237000000.0      2009.0                  936.0        7.9          1.78
# 1  300000000.0      2007.0                 5000.0        7.1          2.35
# 2  245000000.0      2015.0                  393.0        6.8          2.35
# 3  250000000.0      2012.0                23000.0        8.5          2.35
# 4          NaN         NaN                   12.0        7.1           NaN
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 4                    0
#
# [5 rows x 28 columns]

# %% [markdown]
# ![](images/ch01_dataframe_anatomy.png)

# %% [markdown]
# ### Each row and each column are labeled by an index
# * The label is the bold font text to the left or above the data frame
# * The row labels are usually called the **index**
# * The column labels are simply referred to as the **columns**
# * The rest of the DataFrame are the **data** or the **values**
#
# ### Make the index more meaningful
# By default, pandas uses integers for the row labels (the index) beginning from 0 and ending at n-1 where n is the number of rows.
#
# Any column can be moved into the index, but it's usually more helpful to use a column of unique values.

# %%
movie['movie_title'].is_unique
# Out:
# True

# %%
movie['movie_title'].nunique(), len(movie.movie_title)
# Out:
# (4916, 4916)

# %% [markdown]
# ### Use `set_index` to create index

# %%
movie_idx = movie.set_index('movie_title')
movie_idx.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
#                                             director_facebook_likes  \
# movie_title
# Avatar                                                          0.0
# Pirates of the Caribbean: At World's End                      563.0
# Spectre                                                         0.0
# The Dark Knight Rises                                       22000.0
# Star Wars: Episode VII - The Force Awakens                    131.0
#
#                                             actor_3_facebook_likes  \
# movie_title
# Avatar                                                       855.0
# Pirates of the Caribbean: At World's End                    1000.0
# Spectre                                                      161.0
# The Dark Knight Rises                                      23000.0
# Star Wars: Episode VII - The Force Awakens                     NaN
#
#                                                 actor_2_name  \
# movie_title
# Avatar                                      Joel David Moore
# Pirates of the Caribbean: At World's End       Orlando Bloom
# Spectre                                         Rory Kinnear
# The Dark Knight Rises                         Christian Bale
# Star Wars: Episode VII - The Force Awakens        Rob Walker
#
#                                             actor_1_facebook_likes  \
# movie_title
# Avatar                                                      1000.0
# Pirates of the Caribbean: At World's End                   40000.0
# Spectre                                                    11000.0
# The Dark Knight Rises                                      27000.0
# Star Wars: Episode VII - The Force Awakens                   131.0
#
#                                                   gross  \
# movie_title
# Avatar                                      760505847.0
# Pirates of the Caribbean: At World's End    309404152.0
# Spectre                                     200074175.0
# The Dark Knight Rises                       448130642.0
# Star Wars: Episode VII - The Force Awakens          NaN
#
#                                                                      genres  \
# movie_title
# Avatar                                      Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End           Action|Adventure|Fantasy
# Spectre                                           Action|Adventure|Thriller
# The Dark Knight Rises                                       Action|Thriller
# Star Wars: Episode VII - The Force Awakens                      Documentary
#
#                                                    ...           \
# movie_title                                        ...
# Avatar                                             ...
# Pirates of the Caribbean: At World's End           ...
# Spectre                                            ...
# The Dark Knight Rises                              ...
# Star Wars: Episode VII - The Force Awakens         ...
#
#                                            num_user_for_reviews  language  \
# movie_title
# Avatar                                                   3054.0   English
# Pirates of the Caribbean: At World's End                 1238.0   English
# Spectre                                                   994.0   English
# The Dark Knight Rises                                    2701.0   English
# Star Wars: Episode VII - The Force Awakens                  NaN       NaN
#
#                                             country content_rating  \
# movie_title
# Avatar                                          USA          PG-13
# Pirates of the Caribbean: At World's End        USA          PG-13
# Spectre                                          UK          PG-13
# The Dark Knight Rises                           USA          PG-13
# Star Wars: Episode VII - The Force Awakens      NaN            NaN
#
#                                                  budget title_year  \
# movie_title
# Avatar                                      237000000.0     2009.0
# Pirates of the Caribbean: At World's End    300000000.0     2007.0
# Spectre                                     245000000.0     2015.0
# The Dark Knight Rises                       250000000.0     2012.0
# Star Wars: Episode VII - The Force Awakens          NaN        NaN
#
#                                            actor_2_facebook_likes  imdb_score  \
# movie_title
# Avatar                                                      936.0         7.9
# Pirates of the Caribbean: At World's End                   5000.0         7.1
# Spectre                                                     393.0         6.8
# The Dark Knight Rises                                     23000.0         8.5
# Star Wars: Episode VII - The Force Awakens                   12.0         7.1
#
#                                            aspect_ratio movie_facebook_likes
# movie_title
# Avatar                                             1.78                33000
# Pirates of the Caribbean: At World's End           2.35                    0
# Spectre                                            2.35                85000
# The Dark Knight Rises                              2.35               164000
# Star Wars: Episode VII - The Force Awakens          NaN                    0
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Selecting Subsets of Data
#
# **What is a subset of data?** A subset of data means that we will select particular rows and columns to return as a new DataFrame.
#
# See the [Indexing and Selecting Data in the documentation](http://pandas.pydata.org/pandas-docs/stable/indexing.html)
#
# ### Dividing up the universe of subset selection
# To help get a bird's eye view of subset selection, we can divide up our ability to select subsets into two groups:
# * Selection by the indexers `[]`, `.iloc`, `.loc`
# * Selection with methods
#
# ### Selection with the indexers is much more common
# Whenever some talks about subset selection in pandas, it is almost always meant as selection with the indexers. There are some methods that can select subsets of data but they are not the primary means for doing so.
#
# We will only focus on the indexers for the rest of this section.
#
# ### Selection by label, integer location and boolean indexing
# There are three independent ways to select subsets of data with the indexers
# * By label
# * By integer location
# * With boolean indexing
#
# Boolean indexing is a fairly involved type of selection and will be talked about a little later. For now, we will concentrate on selection by label and by integer location
#
# ### Pandas dual reference to rows and columns
# As we talked about earlier, each row and each column in the DataFrame has a label.
#
# But! Each row and column also may be referred to their integer location. The integer location begins with 0 for the first row/column and ends at n-1.
#
# This means that there is a dual reference for each row and column. You can refer to them by their **label** or **integer location**
#
# ### Integer Location is know as 'Position' in the documentation
# The documentation use the word **position** to refer to integer location. I really don't like this name as integer location is more verbose, but you need to be aware of when you read through the documentation.
#
# ### Selection by integer location with Python lists
# Let's take a step back for a moment and look at selection with Python lists. Python lists allow for selection of data only through integer location. You can use a single integer or slice notation to make the selection.

# %%
some_list = ['a', 'two', 10, 4, 0, 'asdf', 'mgmt', 434, 99]

# %%
some_list[5]
# Out:
# 'asdf'

# %%
some_list[-2]
# Out:
# 434

# %%
some_list[:3]
# Out:
# ['a', 'two', 10]

# %%
some_list[10:20]
# Out:
# []

# %%
some_list[2:8:3]
# Out:
# [10, 'asdf']

# %%
some_list[slice(3, 6)]
# Out:
# [4, 0, 'asdf']

# %%
some_list[slice(2, None, 3)]
# Out:
# [10, 'asdf', 99]

# %%
some_list[slice(3)]
# Out:
# ['a', 'two', 10]

# %%
slice(3)
# Out:
# slice(None, 3, None)

# %% [markdown]
# ### Selection by label with Python dictionaries
# Let's continue with core Python and use a Python dictionary to make a selection. All values in each dictionary are labeled by a **key**. We use this key to make single selections.

# %%
d = {'a':1, 'b':2, 't':20, 'z':26, 'A':27}

# %%
d['b']
# Out:
# 2

# %%
d['A']
# Out:
# 27

# %% [markdown]
# ### Pandas has power of lists and dictionaries
# Pandas DataFrames and Series are able to make selections with integers like a list and with labels like a dictionary.
#
# ### Making our first selection with just the indexing operator, `[]`
#
# We are finally ready to make a selection of data! Remember that there are three primary indexers: `[]`, `.loc` and `.iloc`. We will begin with the just the **indexing operator**. This is simply the square brackets that immediately follow a DataFrame or Series.
#
# This one little operator is actually quite confusing but its **primary purpose** is to select a column or columns from a DataFrame by **column label**.
#
# ### A single label as a string selects one column as a Series

# %%
movie_idx['duration'].head()
# Out:
# movie_title
# Avatar                                        178.0
# Pirates of the Caribbean: At World's End      169.0
# Spectre                                       148.0
# The Dark Knight Rises                         164.0
# Star Wars: Episode VII - The Force Awakens      NaN
# Name: duration, dtype: float64

# %% [markdown]
# ### A list of string labels selects those columns as a DataFrame

# %%
movie_idx[['director_name', 'director_facebook_likes']].head()
# Out:
#                                                 director_name  \
# movie_title
# Avatar                                          James Cameron
# Pirates of the Caribbean: At World's End       Gore Verbinski
# Spectre                                            Sam Mendes
# The Dark Knight Rises                       Christopher Nolan
# Star Wars: Episode VII - The Force Awakens        Doug Walker
#
#                                             director_facebook_likes
# movie_title
# Avatar                                                          0.0
# Pirates of the Caribbean: At World's End                      563.0
# Spectre                                                         0.0
# The Dark Knight Rises                                       22000.0
# Star Wars: Episode VII - The Force Awakens                    131.0

# %% [markdown]
# ### There is more to the indexing operator...
# The indexing operator can also do boolean indexing, which will be discussed further below.
#
# It also has another ability to select rows, but we won't talk about this for now as its terribly confusing.
#
# ### Summary of indexing operator, `[]`
# * The primary purpose of the indexing operator is to select a column or columns
# * Use a single string to select one column as a string
# * Use a list of strings to select multiple columns as a DataFrame
# * It generally is not used to select a subset of rows (it can but is confusing - more on this later)
#
# ### Selection by label with `.loc`
# The `.loc` indexer makes selections **only  by row or column label**. It has the ability to simultaneously select rows and columns. The indexing operator by itself cannot do this.
#
# ### Select rows by label
# When using `.loc`, passing in a string or list of strings will select rows with that matching label. This contrasts with the indexing operator which selects columns.
#
# Let's see an example of selecting two movies as a DataFrame:

# %%
movie_idx.loc[['Avatar', 'The Dark Knight Rises']]
# Out:
#                        color      director_name  num_critic_for_reviews  \
# movie_title
# Avatar                 Color      James Cameron                   723.0
# The Dark Knight Rises  Color  Christopher Nolan                   813.0
#
#                        duration  director_facebook_likes  \
# movie_title
# Avatar                    178.0                      0.0
# The Dark Knight Rises     164.0                  22000.0
#
#                        actor_3_facebook_likes      actor_2_name  \
# movie_title
# Avatar                                  855.0  Joel David Moore
# The Dark Knight Rises                 23000.0    Christian Bale
#
#                        actor_1_facebook_likes        gross  \
# movie_title
# Avatar                                 1000.0  760505847.0
# The Dark Knight Rises                 27000.0  448130642.0
#
#                                                 genres         ...           \
# movie_title                                                    ...
# Avatar                 Action|Adventure|Fantasy|Sci-Fi         ...
# The Dark Knight Rises                  Action|Thriller         ...
#
#                       num_user_for_reviews  language  country content_rating  \
# movie_title
# Avatar                              3054.0   English      USA          PG-13
# The Dark Knight Rises               2701.0   English      USA          PG-13
#
#                             budget title_year actor_2_facebook_likes  \
# movie_title
# Avatar                 237000000.0     2009.0                  936.0
# The Dark Knight Rises  250000000.0     2012.0                23000.0
#
#                        imdb_score aspect_ratio movie_facebook_likes
# movie_title
# Avatar                        7.9         1.78                33000
# The Dark Knight Rises         8.5         2.35               164000
#
# [2 rows x 27 columns]

# %% [markdown]
# ### Selecting a single row with `.loc`
# Use a single string to select one single row as a Series.

# %%
movie_idx.loc['Avatar'].head()
# Out:
# color                              Color
# director_name              James Cameron
# num_critic_for_reviews               723
# duration                             178
# director_facebook_likes                0
# Name: Avatar, dtype: object

# %% [markdown]
# ### Using slice notation with .loc
# Just like lists, you can use slice notation with `.loc` to select several rows at once. Notice that `.loc` INCLUDES the last element which is unlike python lists.

# %%
movie_idx.loc['Avatar':'The Dark Knight Rises']
# Out:
#                                           color      director_name  \
# movie_title
# Avatar                                    Color      James Cameron
# Pirates of the Caribbean: At World's End  Color     Gore Verbinski
# Spectre                                   Color         Sam Mendes
# The Dark Knight Rises                     Color  Christopher Nolan
#
#                                           num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                     723.0     178.0
# Pirates of the Caribbean: At World's End                   302.0     169.0
# Spectre                                                    602.0     148.0
# The Dark Knight Rises                                      813.0     164.0
#
#                                           director_facebook_likes  \
# movie_title
# Avatar                                                        0.0
# Pirates of the Caribbean: At World's End                    563.0
# Spectre                                                       0.0
# The Dark Knight Rises                                     22000.0
#
#                                           actor_3_facebook_likes  \
# movie_title
# Avatar                                                     855.0
# Pirates of the Caribbean: At World's End                  1000.0
# Spectre                                                    161.0
# The Dark Knight Rises                                    23000.0
#
#                                               actor_2_name  \
# movie_title
# Avatar                                    Joel David Moore
# Pirates of the Caribbean: At World's End     Orlando Bloom
# Spectre                                       Rory Kinnear
# The Dark Knight Rises                       Christian Bale
#
#                                           actor_1_facebook_likes        gross  \
# movie_title
# Avatar                                                    1000.0  760505847.0
# Pirates of the Caribbean: At World's End                 40000.0  309404152.0
# Spectre                                                  11000.0  200074175.0
# The Dark Knight Rises                                    27000.0  448130642.0
#
#                                                                    genres  \
# movie_title
# Avatar                                    Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End         Action|Adventure|Fantasy
# Spectre                                         Action|Adventure|Thriller
# The Dark Knight Rises                                     Action|Thriller
#
#                                                  ...           \
# movie_title                                      ...
# Avatar                                           ...
# Pirates of the Caribbean: At World's End         ...
# Spectre                                          ...
# The Dark Knight Rises                            ...
#
#                                          num_user_for_reviews  language  \
# movie_title
# Avatar                                                 3054.0   English
# Pirates of the Caribbean: At World's End               1238.0   English
# Spectre                                                 994.0   English
# The Dark Knight Rises                                  2701.0   English
#
#                                           country content_rating       budget  \
# movie_title
# Avatar                                        USA          PG-13  237000000.0
# Pirates of the Caribbean: At World's End      USA          PG-13  300000000.0
# Spectre                                        UK          PG-13  245000000.0
# The Dark Knight Rises                         USA          PG-13  250000000.0
#
#                                          title_year actor_2_facebook_likes  \
# movie_title
# Avatar                                       2009.0                  936.0
# Pirates of the Caribbean: At World's End     2007.0                 5000.0
# Spectre                                      2015.0                  393.0
# The Dark Knight Rises                        2012.0                23000.0
#
#                                           imdb_score aspect_ratio  \
# movie_title
# Avatar                                           7.9         1.78
# Pirates of the Caribbean: At World's End         7.1         2.35
# Spectre                                          6.8         2.35
# The Dark Knight Rises                            8.5         2.35
#
#                                          movie_facebook_likes
# movie_title
# Avatar                                                  33000
# Pirates of the Caribbean: At World's End                    0
# Spectre                                                 85000
# The Dark Knight Rises                                  164000
#
# [4 rows x 27 columns]

# %%
movie_idx.loc['The Dark Knight Rises'::1000]
# Out:
#                        color      director_name  num_critic_for_reviews  \
# movie_title
# The Dark Knight Rises  Color  Christopher Nolan                   813.0
# Man of the House       Color      Stephen Herek                    59.0
# Jane Got a Gun         Color     Gavin O'Connor                   123.0
# Woman in Gold          Color       Simon Curtis                   203.0
# Woman Thou Art Loosed  Color    Michael Schultz                    17.0
#
#                        duration  director_facebook_likes  \
# movie_title
# The Dark Knight Rises     164.0                  22000.0
# Man of the House          100.0                     65.0
# Jane Got a Gun             98.0                    149.0
# Woman in Gold             109.0                     64.0
# Woman Thou Art Loosed      94.0                     78.0
#
#                        actor_3_facebook_likes     actor_2_name  \
# movie_title
# The Dark Knight Rises                 23000.0   Christian Bale
# Man of the House                        730.0  Vanessa Ferlito
# Jane Got a Gun                          439.0    Noah Emmerich
# Woman in Gold                           553.0   Frances Fisher
# Woman Thou Art Loosed                   469.0   Kimberly Elise
#
#                        actor_1_facebook_likes        gross  \
# movie_title
# The Dark Knight Rises                 27000.0  448130642.0
# Man of the House                       1000.0   19118247.0
# Jane Got a Gun                        20000.0    1512815.0
# Woman in Gold                         16000.0   33305037.0
# Woman Thou Art Loosed                   912.0    6879730.0
#
#                                         genres         ...           \
# movie_title                                            ...
# The Dark Knight Rises          Action|Thriller         ...
# Man of the House                 Action|Comedy         ...
# Jane Got a Gun            Action|Drama|Western         ...
# Woman in Gold          Biography|Drama|History         ...
# Woman Thou Art Loosed                    Drama         ...
#
#                       num_user_for_reviews  language  country content_rating  \
# movie_title
# The Dark Knight Rises               2701.0   English      USA          PG-13
# Man of the House                      94.0   English      USA          PG-13
# Jane Got a Gun                        56.0   English      USA              R
# Woman in Gold                        147.0   English       UK          PG-13
# Woman Thou Art Loosed                 23.0   English      USA              R
#
#                             budget title_year actor_2_facebook_likes  \
# movie_title
# The Dark Knight Rises  250000000.0     2012.0                23000.0
# Man of the House        40000000.0     2005.0                  923.0
# Jane Got a Gun          25000000.0     2016.0                  617.0
# Woman in Gold           11000000.0     2015.0                  638.0
# Woman Thou Art Loosed          NaN     2004.0                  637.0
#
#                        imdb_score aspect_ratio movie_facebook_likes
# movie_title
# The Dark Knight Rises         8.5         2.35               164000
# Man of the House              5.4         2.35                  779
# Jane Got a Gun                5.8         2.35                    0
# Woman in Gold                 7.3         2.35                34000
# Woman Thou Art Loosed         6.9          NaN                  187
#
# [5 rows x 27 columns]

# %%
movie_idx.loc['Forrest Gump':'My Big Fat Greek Wedding':1000]
# Out:
#                         color    director_name  num_critic_for_reviews  \
# movie_title
# Forrest Gump  Black and White  Robert Zemeckis                   149.0
# Red Eye                 Color       Wes Craven                   224.0
# Bubble Boy              Color      Blair Hayes                    47.0
#
#               duration  director_facebook_likes  actor_3_facebook_likes  \
# movie_title
# Forrest Gump     142.0                      0.0                   194.0
# Red Eye           85.0                      0.0                   178.0
# Bubble Boy        84.0                      2.0                   690.0
#
#                       actor_2_name  actor_1_facebook_likes        gross  \
# movie_title
# Forrest Gump  Siobhan Fallon Hogan                 15000.0  329691196.0
# Red Eye              Carl Gilliard                   332.0   57859105.0
# Bubble Boy          Geoffrey Arend                 15000.0    5002310.0
#
#                                        genres         ...           \
# movie_title                                           ...
# Forrest Gump                     Comedy|Drama         ...
# Red Eye                      Mystery|Thriller         ...
# Bubble Boy    Adventure|Comedy|Romance|Sci-Fi         ...
#
#              num_user_for_reviews  language  country content_rating  \
# movie_title
# Forrest Gump               1398.0   English      USA          PG-13
# Red Eye                     673.0   English      USA          PG-13
# Bubble Boy                  181.0   English      USA          PG-13
#
#                   budget title_year actor_2_facebook_likes  imdb_score  \
# movie_title
# Forrest Gump  55000000.0     1994.0                  294.0         8.8
# Red Eye       26000000.0     2005.0                  285.0         6.5
# Bubble Boy    13000000.0     2001.0                  816.0         5.6
#
#              aspect_ratio movie_facebook_likes
# movie_title
# Forrest Gump         2.35                59000
# Red Eye              2.35                    0
# Bubble Boy           2.35                    0
#
# [3 rows x 27 columns]

# %%
slice_obj = slice('Forrest Gump','My Big Fat Greek Wedding', 1000)

# %%
movie_idx[slice_obj]
# Out:
#                         color    director_name  num_critic_for_reviews  \
# movie_title
# Forrest Gump  Black and White  Robert Zemeckis                   149.0
# Red Eye                 Color       Wes Craven                   224.0
# Bubble Boy              Color      Blair Hayes                    47.0
#
#               duration  director_facebook_likes  actor_3_facebook_likes  \
# movie_title
# Forrest Gump     142.0                      0.0                   194.0
# Red Eye           85.0                      0.0                   178.0
# Bubble Boy        84.0                      2.0                   690.0
#
#                       actor_2_name  actor_1_facebook_likes        gross  \
# movie_title
# Forrest Gump  Siobhan Fallon Hogan                 15000.0  329691196.0
# Red Eye              Carl Gilliard                   332.0   57859105.0
# Bubble Boy          Geoffrey Arend                 15000.0    5002310.0
#
#                                        genres         ...           \
# movie_title                                           ...
# Forrest Gump                     Comedy|Drama         ...
# Red Eye                      Mystery|Thriller         ...
# Bubble Boy    Adventure|Comedy|Romance|Sci-Fi         ...
#
#              num_user_for_reviews  language  country content_rating  \
# movie_title
# Forrest Gump               1398.0   English      USA          PG-13
# Red Eye                     673.0   English      USA          PG-13
# Bubble Boy                  181.0   English      USA          PG-13
#
#                   budget title_year actor_2_facebook_likes  imdb_score  \
# movie_title
# Forrest Gump  55000000.0     1994.0                  294.0         8.8
# Red Eye       26000000.0     2005.0                  285.0         6.5
# Bubble Boy    13000000.0     2001.0                  816.0         5.6
#
#              aspect_ratio movie_facebook_likes
# movie_title
# Forrest Gump         2.35                59000
# Red Eye              2.35                    0
# Bubble Boy           2.35                    0
#
# [3 rows x 27 columns]

# %% [markdown]
# ### Select rows and columns simultaneously with `.loc`
# The nice thing about `.loc` is that you can select rows and columns simultaneously. You do so by separating the row selection and column selection by a comma inside the square brackets following `.loc`.
#
# For instance, if we wanted to select 2 movies and three columns we could do the following:

# %%
movie_idx.loc[['Avatar', 'The Dark Knight Rises'], ['duration', 'color', 'actor_1_name']]
# Out:
#                        duration  color actor_1_name
# movie_title
# Avatar                    178.0  Color  CCH Pounder
# The Dark Knight Rises     164.0  Color    Tom Hardy

# %% [markdown]
# It might be easier to store the row and column selection as variables

# %%
rows = ['Avatar', 'The Dark Knight Rises']
cols = ['duration', 'color', 'actor_1_name']

movie_idx.loc[rows, cols]
# Out:
#                        duration  color actor_1_name
# movie_title
# Avatar                    178.0  Color  CCH Pounder
# The Dark Knight Rises     164.0  Color    Tom Hardy

# %% [markdown]
# The row and column selections can be:
# * a string
# * a list of strings
# * a slice

# %%
movie_idx.loc['Avatar':'The Dark Knight Rises', ['duration', 'color']]
# Out:
#                                           duration  color
# movie_title
# Avatar                                       178.0  Color
# Pirates of the Caribbean: At World's End     169.0  Color
# Spectre                                      148.0  Color
# The Dark Knight Rises                        164.0  Color

# %%
movie_idx.loc['Avatar':'The Dark Knight Rises', 'color']
# Out:
# movie_title
# Avatar                                      Color
# Pirates of the Caribbean: At World's End    Color
# Spectre                                     Color
# The Dark Knight Rises                       Color
# Name: color, dtype: object

# %%
movie_idx.loc['Avatar', 'color']
# Out:
# 'Color'

# %%
# get all rows with a subset of columns
movie_idx.loc[:, 'director_name':'actor_1_name'].head()
# Out:
#                                                 director_name  \
# movie_title
# Avatar                                          James Cameron
# Pirates of the Caribbean: At World's End       Gore Verbinski
# Spectre                                            Sam Mendes
# The Dark Knight Rises                       Christopher Nolan
# Star Wars: Episode VII - The Force Awakens        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
#                                             director_facebook_likes  \
# movie_title
# Avatar                                                          0.0
# Pirates of the Caribbean: At World's End                      563.0
# Spectre                                                         0.0
# The Dark Knight Rises                                       22000.0
# Star Wars: Episode VII - The Force Awakens                    131.0
#
#                                             actor_3_facebook_likes  \
# movie_title
# Avatar                                                       855.0
# Pirates of the Caribbean: At World's End                    1000.0
# Spectre                                                      161.0
# The Dark Knight Rises                                      23000.0
# Star Wars: Episode VII - The Force Awakens                     NaN
#
#                                                 actor_2_name  \
# movie_title
# Avatar                                      Joel David Moore
# Pirates of the Caribbean: At World's End       Orlando Bloom
# Spectre                                         Rory Kinnear
# The Dark Knight Rises                         Christian Bale
# Star Wars: Episode VII - The Force Awakens        Rob Walker
#
#                                             actor_1_facebook_likes  \
# movie_title
# Avatar                                                      1000.0
# Pirates of the Caribbean: At World's End                   40000.0
# Spectre                                                    11000.0
# The Dark Knight Rises                                      27000.0
# Star Wars: Episode VII - The Force Awakens                   131.0
#
#                                                   gross  \
# movie_title
# Avatar                                      760505847.0
# Pirates of the Caribbean: At World's End    309404152.0
# Spectre                                     200074175.0
# The Dark Knight Rises                       448130642.0
# Star Wars: Episode VII - The Force Awakens          NaN
#
#                                                                      genres  \
# movie_title
# Avatar                                      Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End           Action|Adventure|Fantasy
# Spectre                                           Action|Adventure|Thriller
# The Dark Knight Rises                                       Action|Thriller
# Star Wars: Episode VII - The Force Awakens                      Documentary
#
#                                                actor_1_name
# movie_title
# Avatar                                          CCH Pounder
# Pirates of the Caribbean: At World's End        Johnny Depp
# Spectre                                     Christoph Waltz
# The Dark Knight Rises                             Tom Hardy
# Star Wars: Episode VII - The Force Awakens      Doug Walker

# %% [markdown]
# ### Summarizing `.loc`
# The general format is
# ```
# df.loc[row_selection, col_selection]
# ```
#
# Where `row_selection` and `col_selection` can be any of the following:
#
# * A single string
# * A list of strings
# * A slice
# * Can also be a boolean Series or array (discussed later)

# %% [markdown]
# ## Selection by integer location with `.iloc`
# `.iloc` only makes selections by integer location, so you must pass it INTEGERS and only INTEGERS. `.iloc` works similarly as `.loc` so we will cut this section short and provide the summary first. The general form is:
# ```
# df.loc[row_selection, col_selection]
# ```
# Where `row_selection` and `col_selection` can be any of the following:
#
# * A single integer
# * A list of integers
# * A slice
# * Can also be a boolean array (discussed later)

# %%
# select a few rows
movie_idx.iloc[[10, 50, 88]]
# Out:
#                                     color director_name  \
# movie_title
# Batman v Superman: Dawn of Justice  Color   Zack Snyder
# The Great Gatsby                    Color  Baz Luhrmann
# Tomorrowland                        Color     Brad Bird
#
#                                     num_critic_for_reviews  duration  \
# movie_title
# Batman v Superman: Dawn of Justice                   673.0     183.0
# The Great Gatsby                                     490.0     143.0
# Tomorrowland                                         443.0     130.0
#
#                                     director_facebook_likes  \
# movie_title
# Batman v Superman: Dawn of Justice                      0.0
# The Great Gatsby                                     1000.0
# Tomorrowland                                          663.0
#
#                                     actor_3_facebook_likes       actor_2_name  \
# movie_title
# Batman v Superman: Dawn of Justice                  2000.0       Lauren Cohan
# The Great Gatsby                                      77.0  Elizabeth Debicki
# Tomorrowland                                         604.0        Chris Bauer
#
#                                     actor_1_facebook_likes        gross  \
# movie_title
# Batman v Superman: Dawn of Justice                 15000.0  330249062.0
# The Great Gatsby                                   29000.0  144812796.0
# Tomorrowland                                        2000.0   93417865.0
#
#                                                                     genres  \
# movie_title
# Batman v Superman: Dawn of Justice                 Action|Adventure|Sci-Fi
# The Great Gatsby                                             Drama|Romance
# Tomorrowland                        Action|Adventure|Family|Mystery|Sci-Fi
#
#                                            ...          num_user_for_reviews  \
# movie_title                                ...
# Batman v Superman: Dawn of Justice         ...                        3018.0
# The Great Gatsby                           ...                         753.0
# Tomorrowland                               ...                         497.0
#
#                                     language    country content_rating  \
# movie_title
# Batman v Superman: Dawn of Justice   English        USA          PG-13
# The Great Gatsby                     English  Australia          PG-13
# Tomorrowland                         English        USA             PG
#
#                                          budget title_year  \
# movie_title
# Batman v Superman: Dawn of Justice  250000000.0     2016.0
# The Great Gatsby                    105000000.0     2013.0
# Tomorrowland                        190000000.0     2015.0
#
#                                    actor_2_facebook_likes  imdb_score  \
# movie_title
# Batman v Superman: Dawn of Justice                 4000.0         6.9
# The Great Gatsby                                    509.0         7.3
# Tomorrowland                                        638.0         6.5
#
#                                    aspect_ratio movie_facebook_likes
# movie_title
# Batman v Superman: Dawn of Justice         2.35               197000
# The Great Gatsby                           2.35               115000
# Tomorrowland                               2.20                37000
#
# [3 rows x 27 columns]

# %%
# select a single row as a Series
movie_idx.iloc[999].head()
# Out:
# color                          Color
# director_name              Brad Bird
# num_critic_for_reviews           162
# duration                          90
# director_facebook_likes          663
# Name: The Iron Giant, dtype: object

# %%
# select using a slice - exclusive of last integer location just like python lists
movie_idx.iloc[105:110]
# Out:
#                                  color      director_name  \
# movie_title
# Poseidon                         Color  Wolfgang Petersen
# Alice Through the Looking Glass  Color        James Bobin
# Shrek the Third                  Color       Chris Miller
# Warcraft                         Color       Duncan Jones
# Terminator Genisys               Color        Alan Taylor
#
#                                  num_critic_for_reviews  duration  \
# movie_title
# Poseidon                                          231.0      98.0
# Alice Through the Looking Glass                   218.0     113.0
# Shrek the Third                                   227.0      93.0
# Warcraft                                          275.0     123.0
# Terminator Genisys                                474.0     126.0
#
#                                  director_facebook_likes  \
# movie_title
# Poseidon                                           249.0
# Alice Through the Looking Glass                     33.0
# Shrek the Third                                     50.0
# Warcraft                                             0.0
# Terminator Genisys                                 230.0
#
#                                  actor_3_facebook_likes   actor_2_name  \
# movie_title
# Poseidon                                          702.0     Mike Vogel
# Alice Through the Looking Glass                 11000.0   Alan Rickman
# Shrek the Third                                   692.0      Eric Idle
# Warcraft                                          648.0  Callum Rennie
# Terminator Genisys                               2000.0  Emilia Clarke
#
#                                  actor_1_facebook_likes        gross  \
# movie_title
# Poseidon                                        87000.0   60655503.0
# Alice Through the Looking Glass                 40000.0   76846624.0
# Shrek the Third                                  3000.0  320706665.0
# Warcraft                                         3000.0   46978995.0
# Terminator Genisys                              24000.0   89732035.0
#
#                                                                     genres  \
# movie_title
# Poseidon                                   Action|Adventure|Drama|Thriller
# Alice Through the Looking Glass                   Adventure|Family|Fantasy
# Shrek the Third                  Adventure|Animation|Comedy|Family|Fantasy
# Warcraft                                          Action|Adventure|Fantasy
# Terminator Genisys                                 Action|Adventure|Sci-Fi
#
#                                         ...          num_user_for_reviews  \
# movie_title                             ...
# Poseidon                                ...                         629.0
# Alice Through the Looking Glass         ...                         131.0
# Shrek the Third                         ...                         326.0
# Warcraft                                ...                         781.0
# Terminator Genisys                      ...                         867.0
#
#                                  language  country content_rating  \
# movie_title
# Poseidon                          English      USA          PG-13
# Alice Through the Looking Glass   English      USA             PG
# Shrek the Third                   English      USA             PG
# Warcraft                          English      USA          PG-13
# Terminator Genisys                English      USA          PG-13
#
#                                       budget title_year  \
# movie_title
# Poseidon                         160000000.0     2006.0
# Alice Through the Looking Glass  170000000.0     2016.0
# Shrek the Third                  160000000.0     2007.0
# Warcraft                         160000000.0     2016.0
# Terminator Genisys               155000000.0     2015.0
#
#                                 actor_2_facebook_likes  imdb_score  \
# movie_title
# Poseidon                                        2000.0         5.6
# Alice Through the Looking Glass                25000.0         6.4
# Shrek the Third                                  795.0         6.1
# Warcraft                                         716.0         7.3
# Terminator Genisys                             10000.0         6.6
#
#                                 aspect_ratio movie_facebook_likes
# movie_title
# Poseidon                                2.35                    0
# Alice Through the Looking Glass         1.85                30000
# Shrek the Third                         1.85                    0
# Warcraft                                2.35                89000
# Terminator Genisys                      2.35                82000
#
# [5 rows x 27 columns]

# %%
# select rows and columns simultaneously with lists
movie_idx.iloc[[1, 100,1000], [9, 4, 1]]
# Out:
#                                                             genres  \
# movie_title
# Pirates of the Caribbean: At World's End  Action|Adventure|Fantasy
# The Fast and the Furious                     Action|Crime|Thriller
# The Life Aquatic with Steve Zissou          Adventure|Comedy|Drama
#
#                                           director_facebook_likes  \
# movie_title
# Pirates of the Caribbean: At World's End                    563.0
# The Fast and the Furious                                    357.0
# The Life Aquatic with Steve Zissou                            0.0
#
#                                            director_name
# movie_title
# Pirates of the Caribbean: At World's End  Gore Verbinski
# The Fast and the Furious                       Rob Cohen
# The Life Aquatic with Steve Zissou          Wes Anderson

# %%
movie_idx.iloc[[1, 100,1000], 6::-1]
# Out:
#                                              actor_2_name  \
# movie_title
# Pirates of the Caribbean: At World's End    Orlando Bloom
# The Fast and the Furious                       Vin Diesel
# The Life Aquatic with Steve Zissou        Anjelica Huston
#
#                                           actor_3_facebook_likes  \
# movie_title
# Pirates of the Caribbean: At World's End                  1000.0
# The Fast and the Furious                                  4000.0
# The Life Aquatic with Steve Zissou                         639.0
#
#                                           director_facebook_likes  duration  \
# movie_title
# Pirates of the Caribbean: At World's End                    563.0     169.0
# The Fast and the Furious                                    357.0     106.0
# The Life Aquatic with Steve Zissou                            0.0     119.0
#
#                                           num_critic_for_reviews  \
# movie_title
# Pirates of the Caribbean: At World's End                   302.0
# The Fast and the Furious                                   187.0
# The Life Aquatic with Steve Zissou                         259.0
#
#                                            director_name  color
# movie_title
# Pirates of the Caribbean: At World's End  Gore Verbinski  Color
# The Fast and the Furious                       Rob Cohen  Color
# The Life Aquatic with Steve Zissou          Wes Anderson  Color

# %%
movie_idx.iloc[140:144, 19]
# Out:
# movie_title
# Mission: Impossible III    USA
# White House Down           USA
# Mars Needs Moms            USA
# Flushed Away                UK
# Name: country, dtype: object

# %% [markdown]
# # The deprecated `.ix`

# %% [raw]
# NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`! NEVER USE `.ix`!

# %% [markdown]
# The first indexer created for pandas was `.ix` which was versatile and able to simultaneously select rows and columns by both integer location AND label. It is still available in pandas but will give you a deprecation warning.

# %%
# never do this!!!
movie_idx.ix[['Avatar', 'The Dark Knight Rises'], 5:10]
# Out:
#                        actor_3_facebook_likes      actor_2_name  \
# movie_title
# Avatar                                  855.0  Joel David Moore
# The Dark Knight Rises                 23000.0    Christian Bale
#
#                        actor_1_facebook_likes        gross  \
# movie_title
# Avatar                                 1000.0  760505847.0
# The Dark Knight Rises                 27000.0  448130642.0
#
#                                                 genres
# movie_title
# Avatar                 Action|Adventure|Fantasy|Sci-Fi
# The Dark Knight Rises                  Action|Thriller

# %% [markdown]
# ## How to simultaneously select by label and integer location without `.ix`
# It is rare that you would ever need to do this but it will still come up from time to time.
#
# To do this, you will need to convert your labels to integers or vice versa.
#
# Let's say you wanted to select the rows 10 and 50 with columns duration and color. You can get the integer location of the columns with the `get_indexer` method (which works only on the index or columns attribute).

# %%
col_ints = movie_idx.columns.get_indexer(['duration', 'color'])
col_ints
# Out:
# array([3, 0])

# %%
movie_idx.iloc[[10,50], col_ints]
# Out:
#                                     duration  color
# movie_title
# Batman v Superman: Dawn of Justice     183.0  Color
# The Great Gatsby                       143.0  Color

# %% [markdown]
# Or you can get the labels of the 10th and 50th rows

# %%
row_labels = movie_idx.index[[10, 50]]
row_labels
# Out:
# Index(['Batman v Superman: Dawn of Justice', 'The Great Gatsby'], dtype='object', name='movie_title')

# %%
movie_idx.loc[row_labels, ['duration', 'color']]
# Out:
#                                     duration  color
# movie_title
# Batman v Superman: Dawn of Justice     183.0  Color
# The Great Gatsby                       143.0  Color

# %% [markdown]
# # Automatic Alignment of the index

# %%
df = pd.DataFrame(data={'Apples':[10, 4, 8], 'Bananas':[3, 4, 10]},
                  index=['Texas', 'California', 'Florida'])
df
# Out:
#             Apples  Bananas
# Texas           10        3
# California       4        4
# Florida          8       10

# %%
df['Oranges'] = [3, 6, 7]

# %%
df
# Out:
#             Apples  Bananas  Oranges
# Texas           10        3        3
# California       4        4        6
# Florida          8       10        7

# %%
s = pd.Series([4, 9, 3])

# %%
df['Mangos'] = s

# %%
df
# Out:
#             Apples  Bananas  Oranges  Mangos
# Texas           10        3        3     NaN
# California       4        4        6     NaN
# Florida          8       10        7     NaN

# %%
s = pd.Series(data=[4, 9, 3], index=['Florida', 'Texas', 'California'])
s
# Out:
# Florida       4
# Texas         9
# California    3
# dtype: int64

# %%
df['Mangos'] = s

# %%
df
# Out:
#             Apples  Bananas  Oranges  Mangos
# Texas           10        3        3       9
# California       4        4        6       3
# Florida          8       10        7       4

# %% [markdown]
# # Exploding Indexes

# %%
employee = pd.read_csv('data/employee.csv', index_col='RACE')
employee.head()
# Out:
#                  UNIQUE_ID               POSITION_TITLE  \
# RACE
# Hispanic/Latino          0  ASSISTANT DIRECTOR (EX LVL)
# Hispanic/Latino          1            LIBRARY ASSISTANT
# White                    2               POLICE OFFICER
# White                    3            ENGINEER/OPERATOR
# White                    4                  ELECTRICIAN
#
#                                     DEPARTMENT  BASE_SALARY EMPLOYMENT_TYPE  \
# RACE
# Hispanic/Latino    Municipal Courts Department     121862.0       Full Time
# Hispanic/Latino                        Library      26125.0       Full Time
# White            Houston Police Department-HPD      45279.0       Full Time
# White            Houston Fire Department (HFD)      63166.0       Full Time
# White              General Services Department      56347.0       Full Time
#
#                  GENDER EMPLOYMENT_STATUS   HIRE_DATE    JOB_DATE
# RACE
# Hispanic/Latino  Female            Active  2006-06-12  2012-10-13
# Hispanic/Latino  Female            Active  2000-07-19  2010-09-18
# White              Male            Active  2015-02-03  2015-02-03
# White              Male            Active  1982-02-08  1991-05-25
# White              Male            Active  1989-06-19  1994-10-22

# %%
salary1 = employee['BASE_SALARY']
salary2 = employee['BASE_SALARY']
salary1 is salary2
# Out:
# True

# %%
salary1 = employee['BASE_SALARY'].copy()
salary2 = employee['BASE_SALARY'].copy()
salary1 is salary2
# Out:
# False

# %%
salary1 = salary1.sort_index()
salary1.head()
# Out:
# RACE
# American Indian or Alaskan Native    78355.0
# American Indian or Alaskan Native    81239.0
# American Indian or Alaskan Native    60347.0
# American Indian or Alaskan Native    68299.0
# American Indian or Alaskan Native    26125.0
# Name: BASE_SALARY, dtype: float64

# %%
salary2.head()
# Out:
# RACE
# Hispanic/Latino    121862.0
# Hispanic/Latino     26125.0
# White               45279.0
# White               63166.0
# White               56347.0
# Name: BASE_SALARY, dtype: float64

# %%
salary_add = salary1 + salary2
salary_add.head()
# Out:
# RACE
# American Indian or Alaskan Native    138702.0
# American Indian or Alaskan Native    156710.0
# American Indian or Alaskan Native    176891.0
# American Indian or Alaskan Native    159594.0
# American Indian or Alaskan Native    127734.0
# Name: BASE_SALARY, dtype: float64

# %% [markdown]
# ## Filling values with unequal indexes

# %%
baseball_14 = pd.read_csv('data/baseball14.csv', index_col='playerID')
baseball_15 = pd.read_csv('data/baseball15.csv',index_col='playerID')

# %%
baseball_14.head()
# Out:
#            yearID  stint teamID lgID    G   AB   R    H  2B  3B  ...    RBI  \
# playerID                                                         ...
# altuvjo01    2014      1    HOU   AL  158  660  85  225  47   3  ...   59.0
# cartech02    2014      1    HOU   AL  145  507  68  115  21   1  ...   88.0
# castrja01    2014      1    HOU   AL  126  465  43  103  21   2  ...   56.0
# corpoca01    2014      1    HOU   AL   55  170  22   40   6   0  ...   19.0
# dominma01    2014      1    HOU   AL  157  564  51  121  17   0  ...   57.0
#
#              SB   CS  BB     SO  IBB  HBP   SH   SF  GIDP
# playerID
# altuvjo01  56.0  9.0  36   53.0  7.0  5.0  1.0  5.0  20.0
# cartech02   5.0  2.0  56  182.0  6.0  5.0  0.0  4.0  12.0
# castrja01   1.0  0.0  34  151.0  1.0  9.0  1.0  3.0  11.0
# corpoca01   0.0  0.0  14   37.0  0.0  3.0  1.0  2.0   3.0
# dominma01   0.0  1.0  29  125.0  2.0  5.0  2.0  7.0  23.0
#
# [5 rows x 21 columns]

# %%
baseball_15.head()
# Out:
#            yearID  stint teamID lgID    G   AB   R    H  2B  3B  ...    RBI  \
# playerID                                                         ...
# altuvjo01    2015      1    HOU   AL  154  638  86  200  40   4  ...   66.0
# cartech02    2015      1    HOU   AL  129  391  50   78  17   0  ...   64.0
# castrja01    2015      1    HOU   AL  104  337  38   71  19   0  ...   31.0
# congeha01    2015      1    HOU   AL   73  201  25   46  11   0  ...   33.0
# correca01    2015      1    HOU   AL   99  387  52  108  22   1  ...   68.0
#
#              SB    CS  BB     SO  IBB  HBP   SH   SF  GIDP
# playerID
# altuvjo01  38.0  13.0  33   67.0  8.0  9.0  3.0  6.0  17.0
# cartech02   1.0   2.0  57  151.0  1.0  6.0  0.0  5.0   5.0
# castrja01   0.0   0.0  33  115.0  1.0  2.0  0.0  3.0   5.0
# congeha01   0.0   1.0  23   63.0  0.0  2.0  1.0  2.0   6.0
# correca01  14.0   4.0  40   78.0  2.0  1.0  0.0  4.0  10.0
#
# [5 rows x 21 columns]

# %%
hits_14 = baseball_14['H']
hits_15 = baseball_15['H']

# %%
(hits_14 + hits_15).head()
# Out:
# playerID
# altuvjo01    425.0
# cartech02    193.0
# castrja01    174.0
# congeha01      NaN
# corpoca01      NaN
# Name: H, dtype: float64

# %%
hits_14.add(hits_15, fill_value=0).head()
# Out:
# playerID
# altuvjo01    425.0
# cartech02    193.0
# castrja01    174.0
# congeha01     46.0
# corpoca01     40.0
# Name: H, dtype: float64

# %%
df_14 = baseball_14[['G','AB', 'R', 'H']]
df_15 = baseball_15[['AB', 'R', 'H', 'HR']]

# %%
(df_14 + df_15).head(10).style.highlight_null('yellow')
# Out:
# <style  type="text/css" >
#     #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow0_col1 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow0_col3 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow1_col1 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow1_col3 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow2_col1 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow2_col3 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow3_col0 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow3_col1 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow3_col2 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow3_col3 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow3_col4 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow4_col0 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow4_col1 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow4_col2 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow4_col3 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow4_col4 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow5_col0 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow5_col1 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow5_col2 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow5_col3 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow5_col4 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow6_col0 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow6_col1 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow6_col2 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow6_col3 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow6_col4 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow7_col0 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow7_col1 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow7_col2 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow7_col3 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow7_col4 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow8_col0 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow8_col1 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow8_col2 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow8_col3 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow8_col4 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow9_col0 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow9_col1 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow9_col2 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow9_col3 {
#             background-color:  yellow;
#         }    #T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow9_col4 {
#             background-color:  yellow;
#         }</style>
# <table id="T_a6a04602_cfe4_11e7_9c3c_b8e85647e68c" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >AB</th>
#         <th class="col_heading level0 col1" >G</th>
#         <th class="col_heading level0 col2" >H</th>
#         <th class="col_heading level0 col3" >HR</th>
#         <th class="col_heading level0 col4" >R</th>
#     </tr>    <tr>
#         <th class="index_name level0" >playerID</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_a6a04602_cfe4_11e7_9c3c_b8e85647e68clevel0_row0" class="row_heading level0 row0" >altuvjo01</th>
#         <td id="T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow0_col0" class="data row0 col0" >1298</td>
#         <td id="T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow0_col1" class="data row0 col1" >nan</td>
#         <td id="T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow0_col2" class="data row0 col2" >425</td>
#         <td id="T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow0_col3" class="data row0 col3" >nan</td>
#         <td id="T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow0_col4" class="data row0 col4" >171</td>
#     </tr>    <tr>
#         <th id="T_a6a04602_cfe4_11e7_9c3c_b8e85647e68clevel0_row1" class="row_heading level0 row1" >cartech02</th>
#         <td id="T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow1_col0" class="data row1 col0" >898</td>
#         <td id="T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow1_col1" class="data row1 col1" >nan</td>
#         <td id="T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow1_col2" class="data row1 col2" >193</td>
#         <td id="T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow1_col3" class="data row1 col3" >nan</td>
#         <td id="T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow1_col4" class="data row1 col4" >118</td>
#     </tr>    <tr>
#         <th id="T_a6a04602_cfe4_11e7_9c3c_b8e85647e68clevel0_row2" class="row_heading level0 row2" >castrja01</th>
#         <td id="T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow2_col0" class="data row2 col0" >802</td>
#         <td id="T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow2_col1" class="data row2 col1" >nan</td>
#         <td id="T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow2_col2" class="data row2 col2" >174</td>
#         <td id="T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow2_col3" class="data row2 col3" >nan</td>
#         <td id="T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow2_col4" class="data row2 col4" >81</td>
#     </tr>    <tr>
#         <th id="T_a6a04602_cfe4_11e7_9c3c_b8e85647e68clevel0_row3" class="row_heading level0 row3" >congeha01</th>
#         <td id="T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow3_col0" class="data row3 col0" >nan</td>
#         <td id="T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow3_col1" class="data row3 col1" >nan</td>
#         <td id="T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow3_col2" class="data row3 col2" >nan</td>
#         <td id="T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow3_col3" class="data row3 col3" >nan</td>
#         <td id="T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow3_col4" class="data row3 col4" >nan</td>
#     </tr>    <tr>
#         <th id="T_a6a04602_cfe4_11e7_9c3c_b8e85647e68clevel0_row4" class="row_heading level0 row4" >corpoca01</th>
#         <td id="T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow4_col0" class="data row4 col0" >nan</td>
#         <td id="T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow4_col1" class="data row4 col1" >nan</td>
#         <td id="T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow4_col2" class="data row4 col2" >nan</td>
#         <td id="T_a6a04602_cfe4_11e7_9c3c_b8e85647e68crow4_col3" class="data row4 col3" >nan</td>
#         <td id="T_a6a04602_cfe4_11e7_9c3c_b8e85647

# %% [markdown]
# # `sum(s)` vs `s.sum()`

# %%
salary = employee['BASE_SALARY'].dropna()

# %%
salary.sum()
# Out:
# 105178319.0

# %%
sum(salary)
# Out:
# 105178319.0

# %%
# %timeit salary.sum()
# Out:
# 71.3 µs ± 3.49 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %timeit sum(salary)
# Out:
# 63.2 µs ± 1.8 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
s = salary.sample(n=10000000, replace=True)

# %%
# %timeit s.sum()
# Out:
# 61.1 ms ± 2.53 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit sum(s)
# Out:
# 433 ms ± 11.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
some_list = s.tolist()

# %%
# %timeit sum(some_list)
# Out:
# 55.8 ms ± 2.08 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# Drop down into numpy for best performance

# %%
# %timeit s.values.sum()
# Out:
# 5.07 ms ± 676 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# # `apply` vs `map`
# Both `map` and `apply` can apply a function to a Series of data, but only `map` can transform old to new values with a dictionary:

# %%
s = pd.Series(np.random.randint(0, 4, 10))
mapping = {0:'low', 1: 'low', 2:'high', 3:'high'}
s
# Out:
# 0    1
# 1    0
# 2    3
# 3    2
# 4    3
# 5    2
# 6    3
# 7    1
# 8    0
# 9    0
# dtype: int64

# %%
s.map(mapping)
# Out:
# 0     low
# 1     low
# 2    high
# 3    high
# 4    high
# 5    high
# 6    high
# 7     low
# 8     low
# 9     low
# dtype: object

# %%
def square_me(x):
    return x ** 2

# %%
s.map(square_me)
# Out:
# 0    1
# 1    0
# 2    9
# 3    4
# 4    9
# 5    4
# 6    9
# 7    1
# 8    0
# 9    0
# dtype: int64

# %%
s.apply(square_me)
# Out:
# 0    1
# 1    0
# 2    9
# 3    4
# 4    9
# 5    4
# 6    9
# 7    1
# 8    0
# 9    0
# dtype: int64

# %% [markdown]
# # Apply is usually unnecessary
# It's also slow. Let's take a DataFrame with two columns of integers that represent two legs of a right triangle. Let's calculate the hypotenuse:

# %%
df = pd.DataFrame(np.random.randint(1,10, (100000, 2)), columns=['a', 'b'])

# %%
df.head()
# Out:
#    a  b
# 0  5  3
# 1  4  7
# 2  5  7
# 3  2  6
# 4  3  1

# %%
def calc_hyp(s):
    a = s['a']
    b = s['b']
    return np.sqrt(a ** 2 + b ** 2)

# %%
df.apply(calc_hyp, axis='columns').head(10)
# Out:
# 0     5.830952
# 1     8.062258
# 2     8.602325
# 3     6.324555
# 4     3.162278
# 5     7.810250
# 6     5.830952
# 7     4.472136
# 8    10.000000
# 9     5.000000
# dtype: float64

# %%
# %timeit df.apply(calc_hyp, axis='columns')
# Out:
# 2.53 s ± 31.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit np.sqrt(df['a'] ** 2 + df['b'] ** 2)
# Out:
# 2.73 ms ± 12.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
